# %% [markdown]
# ### Import CSV

# %%
import pandas as pd

# %%
url="https://ballotpedia.org/Gasoline_costs_by_state,_2018"

# %%
gas_table=pd.read_html(url)
main_table=gas_table[1]
main_table
# Out:
#    Average gasoline prices by state, July 25, 2018  \
#                                              State
# 0                                          Alabama
# 1                                           Alaska
# 2                                          Arizona
# 3                                         Arkansas
# 4                                       California
# 5                                         Colorado
# 6                                      Connecticut
# 7                                         Delaware
# 8                             District of Columbia
# 9                                          Florida
# 10                                         Georgia
# 11                                          Hawaii
# 12                                           Idaho
# 13                                        Illinois
# 14                                         Indiana
# 15                                            Iowa
# ...
