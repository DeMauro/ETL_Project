# %%
import pandas as pd
import datetime

# %%
cars = "../Resources/vehicles.csv"

# %%
vehicles_df = pd.read_csv(cars)
vehicles_df
# Out:
#                 id                                                url  \
# 0       7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...
# 1       7088745301  https://greensboro.craigslist.org/ctd/d/bmw-3-...
# 2       7088744126  https://greensboro.craigslist.org/cto/d/greens...
# 3       7088743681  https://greensboro.craigslist.org/ctd/d/cary-2...
# 4       7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...
# ...            ...                                                ...
# 539754  7076296329  https://syracuse.craigslist.org/cto/d/mottvill...
# 539755  7088752165  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539756  7088749883  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539757  7088747986  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539758  7082122917  https://stcloud.craigslist.org/ctd/d/wadena-20...
#
#             region                         region_url  price    year  \
# ...

# %%
test=vehicles_df[vehicles_df['manufacturer'].notna()]
price_fix=vehicles_df[vehicles_df['price'] > 0]
new_df=price_fix[price_fix['model'].notna()]
new_df
# Out:
#                 id                                                url  \
# 0       7088746062  https://greensboro.craigslist.org/ctd/d/cary-2...
# 2       7088744126  https://greensboro.craigslist.org/cto/d/greens...
# 3       7088743681  https://greensboro.craigslist.org/ctd/d/cary-2...
# 4       7074612539  https://lincoln.craigslist.org/ctd/d/gretna-20...
# 5       7088741557  https://greensboro.craigslist.org/ctd/d/cary-2...
# ...            ...                                                ...
# 539753  7088754084  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539755  7088752165  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539756  7088749883  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539757  7088747986  https://greensboro.craigslist.org/ctd/d/cary-2...
# 539758  7082122917  https://stcloud.craigslist.org/ctd/d/wadena-20...
#
#             region                         region_url  price    year  \
# ...

# %%
final_df=new_df[['manufacturer','model','year','price','state','region','lat','long']]
final_df.head()
# Out:
#   manufacturer              model    year  price state      region      lat  \
# 0        acura                 tl  2012.0  10299    nc  greensboro  35.7636
# 2       jaguar                 xf  2011.0   9500    nc  greensboro  36.1032
# 3        honda            element  2004.0   3995    nc  greensboro  35.7636
# 4    chevrolet  silverado k2500hd  2016.0  41988    ne     lincoln  41.1345
# 5          kia           sportage  2015.0  12995    nc  greensboro  35.7636
#
#       long
# 0 -78.7443
# 2 -79.8794
# 3 -78.7443
# 4 -96.2458
# 5 -78.7443

# %%
final_car=final_df.rename(columns={"manufacturer": "Manufacturer",
                            "model":"Model",
                            "year": "Year",
                            "price":"Craigslist Price",
                            "state": "State",
                            "region": "City",
                            "lat": "Lat", 
                            "long": "Long"})

final_car
# Out:
#        Manufacturer              Model    Year  Craigslist Price State  \
# 0             acura                 tl  2012.0             10299    nc
# 2            jaguar                 xf  2011.0              9500    nc
# 3             honda            element  2004.0              3995    nc
# 4         chevrolet  silverado k2500hd  2016.0             41988    ne
# 5               kia           sportage  2015.0             12995    nc
# ...             ...                ...     ...               ...   ...
# 539753        mazda               cx-5  2015.0             12955    nc
# 539755       nissan           frontier  2016.0             13995    nc
# 539756          bmw               335i  2010.0             10995    nc
# 539757        dodge               dart  2015.0              6495    nc
# 539758          gmc             acadia  2008.0              8990    mn
#
#               City      Lat     Long
# 0       greensboro  35.7636 -78.7443
# 2       greensboro  36.1032 -79.8794
# ...

# %%
final_car.to_datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-7ac8a68992be> in <module>
# ----> 1 final_car.to_datetime()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_datetime'
